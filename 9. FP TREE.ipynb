# %%
# !pip install mlxtend==0.23.1
# Out:
# Collecting mlxtend==0.23.1
#   Downloading mlxtend-0.23.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.11/dist-packages (from mlxtend==0.23.1) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.11/dist-packages (from mlxtend==0.23.1) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.11/dist-packages (from mlxtend==0.23.1) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.11/dist-packages (from mlxtend==0.23.1) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from mlxtend==0.23.1) (3.10.0)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from mlxtend==0.23.1) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend==0.23.1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend==0.23.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend==0.23.1) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend==0.23.1) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend==0.23.1) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend==0.23.1) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend==0.23.1) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->mlxtend==0.23.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->mlxtend==0.23.1) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->mlxtend==0.23.1) (2025.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.2->mlxtend==0.23.1) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend==0.23.1) (1.17.0)
# Downloading mlxtend-0.23.1-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 15.5 MB/s eta 0:00:00
# Installing collected packages: mlxtend
#   Attempting uninstall: mlxtend
#     Found existing installation: mlxtend 0.23.4
#     Uninstalling mlxtend-0.23.4:
#       Successfully uninstalled mlxtend-0.23.4
# Successfully installed mlxtend-0.23.1

# %%
import pandas as pd
import numpy as np

# %%
data = [
    ['f','a','c','d','g','i','m','p'],
   ['a','b','c','f','l','m','o'],
    ['b','f','h','j','o'],
    ['b','c','k','s','p'],
   ['a','f','c','e','l','p','m','n']
]

# %%
data
# Out:
# [['f', 'a', 'c', 'd', 'g', 'i', 'm', 'p'],
#  ['a', 'b', 'c', 'f', 'l', 'm', 'o'],
#  ['b', 'f', 'h', 'j', 'o'],
#  ['b', 'c', 'k', 's', 'p'],
#  ['a', 'f', 'c', 'e', 'l', 'p', 'm', 'n']]

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    0  1  2  3  4     5     6     7
# 0  f  a  c  d  g     i     m     p
# 1  a  b  c  f  l     m     o  None
# 2  b  f  h  j  o  None  None  None
# 3  b  c  k  s  p  None  None  None
# 4  a  f  c  e  l     p     m     n

# %%
df.nunique()
# Out:
# 0    3
# 1    4
# 2    3
# 3    5
# 4    4
# 5    3
# 6    2
# 7    2
# dtype: int64

# %%
from mlxtend.preprocessing import TransactionEncoder

te=TransactionEncoder()
te_ar = te.fit(data).transform(data)
te_ar
# Out:
# array([[ True, False,  True,  True, False,  True,  True, False,  True,
#         False, False, False,  True, False, False,  True, False],
#        [ True,  True,  True, False, False,  True, False, False, False,
#         False, False,  True,  True, False,  True, False, False],
#        [False,  True, False, False, False,  True, False,  True, False,
#          True, False, False, False, False,  True, False, False],
#        [False,  True,  True, False, False, False, False, False, False,
#         False,  True, False, False, False, False,  True,  True],
#        [ True, False,  True, False,  True,  True, False, False, False,
#         False, False,  True,  True,  True, False,  True, False]])

# %%
dataset= pd.DataFrame(te_ar,columns=te.columns_)
dataset
# Out:
#        a      b      c      d      e      f      g      h      i      j  \
# 0   True  False   True   True  False   True   True  False   True  False
# 1   True   True   True  False  False   True  False  False  False  False
# 2  False   True  False  False  False   True  False   True  False   True
# 3  False   True   True  False  False  False  False  False  False  False
# 4   True  False   True  False   True   True  False  False  False  False
#
#        k      l      m      n      o      p      s
# 0  False  False   True  False  False   True  False
# 1  False   True   True  False   True  False  False
# 2  False  False  False  False   True  False  False
# 3   True  False  False  False  False   True   True
# 4  False   True   True   True  False   True  False

# %%
from mlxtend.frequent_patterns import fpgrowth
res =fpgrowth(dataset,min_support=0.6,use_colnames=True,max_len=1)

# %%
res
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    support itemsets
# 0      0.8      (f)
# 1      0.8      (c)
# 2      0.6      (p)
# 3      0.6      (m)
# 4      0.6      (a)
# 5      0.6      (b)

# %%
from mlxtend.frequent_patterns import association_rules
res1 = association_rules(res,metric='confidence',min_threshold=0.6)
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
res1[['antecedents','consequents','support','confidence']].sort_values(by='confidence',ascending=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Empty DataFrame
# Columns: [antecedents, consequents, support, confidence]
# Index: []

# %%
import graphviz
graph = graphviz.Digraph('G', format='png')

# Add nodes and edges based on frequent itemsets
for index, row in res.iterrows():
    itemset = ', '.join(row['itemsets'])
    graph.node(itemset)
    for connected_itemset in res['itemsets']:
        if row['itemsets'] != connected_itemset:
            graph.edge(itemset, ', '.join(connected_itemset))

# Render the graph (this saves the file to disk)
graph.render('frequent_itemsets_tree')
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 'frequent_itemsets_tree.png'

# %%
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
